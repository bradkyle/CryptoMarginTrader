# %%
import pandas as pd
import numpy as np
import random as random
import pyarrow as pa 
import pyarrow.parquet as pq
from fastavro import writer, reader, parse_schema
import collections
import ta
import json
import operator

# %%
j = []
with open('./fea.json', 'r') as f:
    j = json.load(f)

# %%
d = []
lb = []
for x, _ in enumerate(j):
    for y in j[x]:
        d.append(y)
        lb.append(y[1])

# %%
x = set(lb)

# %%
dct = {}
for c in x:
    dct[c] = 0

# %%
for x, _ in enumerate(j):
    for y in j[x]:
        dct[y[1]] += y[0]

# %%
sorted_x = sorted(dct.items(), key=operator.itemgetter(1), reverse=True)
